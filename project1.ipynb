# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory"
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, 'html.parser')
# print(soup.prettify())

# %%
covid_data = soup.find('div', class_='sticky-table-collapsible')
covid_data
# Out:
# <div class="sticky-table-collapsible mw-collapsible" data-collapsetext="disable" data-expandtext="enable"><div class="sticky-table-scroll">
# <table class="wikitable sortable sort-under mw-datatable plainrowheaders sticky-table-row1 sticky-table-col2" style="text-align: right;">
# <caption><a href="/wiki/COVID-19" title="COVID-19">COVID-19</a> cases, deaths, and rates by <a class="mw-selflink selflink">location</a><sup class="reference" id="cite_ref-Template:COVID-19_datab_27-0"><a href="#cite_note-Template:COVID-19_datab-27"><span class="cite-bracket">[</span>22<span class="cite-bracket">]</span></a></sup>
# </caption>
# <tbody><tr>
# <th class="unsortable">
# </th>
# <th scope="col">Country
# </th>
# <th scope="col"><abbr title="Deaths per million">Deaths / million</abbr>
# </th>
# <th scope="col">Deaths
# </th>
# <th scope="col">Cases
# </th></tr>
# <tr class="sorttop static-row-header">
# ...

# %%
headers = [th.text.strip() for th in covid_data.find("tr").find_all("th")[1:]]
print(headers)
# Out:
# ['Country', 'Deaths / million', 'Deaths', 'Cases']

# %%
df = pd.DataFrame(columns = headers)
df
# Out:
# Empty DataFrame
# Columns: [Country, Deaths / million, Deaths, Cases]
# Index: []

# %%
rows = []
for row in covid_data.find_all("tr")[1:]:  # Skip the header row
    columns = row.find_all(["td", "th"])  # Include both <td> and <th>
    row_data = [col.text.strip() for col in columns][1:]
    # Ignore empty rows
    if row_data:
        rows.append(row_data)

rows
# Out:
# [['World[a]', '887', '7,088,744', '777,384,606'],
#  ['Peru', '6,601', '220,994', '4,528,708'],
#  ['Bulgaria', '5,679', '38,765', '1,338,348'],
#  ['North Macedonia', '5,428', '9,990', '352,060'],
#  ['Bosnia and Herzegovina', '5,118', '16,404', '404,142'],
#  ['Hungary', '5,072', '49,124', '2,237,773'],
#  ['Croatia', '4,807', '18,783', '1,355,405'],
#  ['Slovenia', '4,686', '9,914', '1,362,820'],
#  ['Georgia', '4,519', '17,151', '1,864,383'],
#  ['Montenegro', '4,317', '2,654', '251,280'],
#  ['Czech Republic', '4,103', '43,802', '4,828,562'],
#  ['Moldova', '4,040', '12,283', '650,918'],
#  ['Latvia', '3,973', '7,475', '977,765'],
#  ['Slovakia', '3,888', '21,280', '1,885,786'],
#  ['Greece', '3,842', '40,006', '5,762,629'],
#  ['San Marino', '3,693', '126', '25,292'],
#  ['Romania', '3,597', '68,960', '3,568,251'],
#  ['United States', '3,562', '1,216,819', '103,436,829'],
#  ['Lithuania', '3,506', '9,877', '1,421,829'],
#  ['United Kingdom', '3,404', '232,112', '25,030,356'],
# ...

# %%
df = pd.DataFrame(rows, columns=headers)
df
# Out:
#                                           Country Deaths / million     Deaths  \
# 0                                        World[a]              887  7,088,744
# 1                                            Peru            6,601    220,994
# 2                                        Bulgaria            5,679     38,765
# 3                                 North Macedonia            5,428      9,990
# 4                          Bosnia and Herzegovina            5,118     16,404
# ..                                            ...              ...        ...
# 234  Saint Helena, Ascension and Tristan da Cunha                0          0
# 235                              Pitcairn Islands                0          0
# 236                                       Tokelau                0          0
# 237                                   North Korea                0          0
# 238                                  Turkmenistan                0          0
#
#            Cases
# ...

# %%
df.to_csv("covid_data.csv", index=False, encoding="utf-8")
print("\nData successfully saved to covid_data.csv!")
# Out:
# Data successfully saved to covid_data.csv!

# %%
df.to_csv(r'C:\Users\KEVIN\Desktop\PYTHON SCRIPTS\covid_data.csv', index = False) #saving directly to the machine

# %%
# READING IN FILES
df2 = pd.read_csv(r'C:\Users\KEVIN\Desktop\PYTHON SCRIPTS\covid_data.csv')
df2
# Out:
#                                           Country Deaths / million     Deaths  \
# 0                                        World[a]              887  7,088,744
# 1                                            Peru            6,601    220,994
# 2                                        Bulgaria            5,679     38,765
# 3                                 North Macedonia            5,428      9,990
# 4                          Bosnia and Herzegovina            5,118     16,404
# ..                                            ...              ...        ...
# 234  Saint Helena, Ascension and Tristan da Cunha                0          0
# 235                              Pitcairn Islands                0          0
# 236                                       Tokelau                0          0
# 237                                   North Korea                0          0
# 238                                  Turkmenistan                0          0
#
#            Cases
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           239 non-null    object
#  1   Deaths / million  239 non-null    object
#  2   Deaths            239 non-null    object
#  3   Cases             239 non-null    object
# dtypes: object(4)
# memory usage: 7.6+ KB

# %%
df.head(5)
# Out:
#                   Country Deaths / million     Deaths        Cases
# 0                World[a]              887  7,088,744  777,384,606
# 1                    Peru            6,601    220,994    4,528,708
# 2                Bulgaria            5,679     38,765    1,338,348
# 3         North Macedonia            5,428      9,990      352,060
# 4  Bosnia and Herzegovina            5,118     16,404      404,142

# %%
df.tail(5)
# Out:
#                                           Country Deaths / million Deaths  \
# 234  Saint Helena, Ascension and Tristan da Cunha                0      0
# 235                              Pitcairn Islands                0      0
# 236                                       Tokelau                0      0
# 237                                   North Korea                0      0
# 238                                  Turkmenistan                0      0
#
#      Cases
# 234  2,166
# 235      4
# 236     80
# 237      0
# 238      0

# %%
df.loc[4]
# Out:
# Country             Bosnia and Herzegovina
# Deaths / million                     5,118
# Deaths                              16,404
# Cases                              404,142
# Name: 4, dtype: object
